# %%
import numpy as np 
import matplotlib.pyplot as plt 

def sigmoid(x, mu, k): 
    input = -k * (x - mu)
    return 1 / ( 1 + np.exp(input))

def simple_nn(x, k): 
    a = 0.4
    b = 0.6
    return 0.5 * sigmoid(x, a, k) - 0.5 * sigmoid(x, b, k) 

X = np.linspace(0, 1, 1000) 

for k in [1, 10, 100, 1000]: 
    Y = simple_nn(X, k)  
    plt.plot(X, Y, label=f"k={k}")
    
plt.legend() 
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

def my_function(x, y):
    return 0.5 * sigmoid(x, 0.3, 1000) - 0.5 * sigmoid(x, 0.7, 1000)

# Create a meshgrid for the (x, y) inputs
x = np.linspace(0, 1, 200)
y = np.linspace(0, 1, 200)
X, Y = np.meshgrid(x, y)
Z = my_function(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('X1 axis')
ax.set_ylabel('X2 axis')
ax.set_zlabel('Z axis')
ax.set_title('3D Plot of the Function')
plt.show()

# %%
def my_function2(x, y):
    first = sigmoid(x, 1000, 0.45) - sigmoid(x, 1000, 0.55) + sigmoid(y, 1000, 0.45) - sigmoid(y, 1000, 0.55)
    print(first)
    second = sigmoid(first, 1000, 1.95)
    return second

# Create a meshgrid for the (x, y) inputs
x = np.linspace(0, 1, 200)
y = np.linspace(0, 1, 200)
X, Y = np.meshgrid(x, y)
Z = my_function2(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('X1 axis')
ax.set_ylabel('X2 axis')
ax.set_zlabel('Z axis')
ax.set_title('3D Plot of the Function')
plt.show()
# Out:
# [[7.38776614e-196 7.39612859e-196 7.40450998e-196 ... 9.46090382e-196
#   9.47395958e-196 9.48704490e-196]
#  [7.39612859e-196 7.40449104e-196 7.41287243e-196 ... 9.46926628e-196
#   9.48232204e-196 9.49540735e-196]
#  [7.40450998e-196 7.41287243e-196 7.42125381e-196 ... 9.47764766e-196
#   9.49070342e-196 9.50378873e-196]
#  ...
#  [9.46090382e-196 9.46926628e-196 9.47764766e-196 ... 1.15340415e-195
#   1.15470973e-195 1.15601826e-195]
#  [9.47395958e-196 9.48232204e-196 9.49070342e-196 ... 1.15470973e-195
#   1.15601530e-195 1.15732383e-195]
#  [9.48704490e-196 9.49540735e-196 9.50378873e-196 ... 1.15601826e-195
#   1.15732383e-195 1.15863237e-195]]
# /tmp/ipykernel_56288/3946181235.py:6: RuntimeWarning: overflow encountered in exp
#   return 1 / ( 1 + np.exp(input))

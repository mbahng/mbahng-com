# %%
import torch
import torch.nn as nn 
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

# Make sure to update where the MNIST dataset is being downloaded to
DATA_PATH = "~/Research/data" 

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5), (0.5))])

training_data = datasets.MNIST(
    root=DATA_PATH,            
    train=True,            
    download=True,          
    transform=transform    
)
test_data = datasets.MNIST(
    root=DATA_PATH,
    train=False,
    download=True,
    transform=transform 
)

train_dataloader = DataLoader(training_data,    # our dataset
                              batch_size=64,    # batch size
                              shuffle=True      # shuffling the data
                            )
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28 * 28, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits    

device = "cuda"

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            # print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return correct

# create helper function to show distribution of model parameters 
import matplotlib.pyplot as plt 
import numpy as np 

def param_hist(model:nn.Module, model_name:str) -> None: 
    res = [] 
    for name, param in model.named_parameters(): 
        res += torch.flatten(param.data).tolist()
        
    plt.hist(res, bins=np.linspace(min(res) -0.1, max(res) + 0.1, 100))
    plt.title(f"Histogram of Parameter Distribution of {model_name}")
    plt.show()

# %%
def run(model): 
    accs = [] 
    model = model.cuda()

    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(
        model.parameters(),     # which parameters to optimize
        lr=1e-3,                 # learning rate 
        momentum=0.9
    )
    epochs = 50
    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")
        train(train_dataloader, model, loss_fn, optimizer)
        acc = test(test_dataloader, model, loss_fn)
        accs.append(acc)
    return accs

# %% [markdown]
# First, we experiment by loading all parameters with $0$ or $1$s.

# %%
model_zero_init = NeuralNetwork()
for name, param in model_zero_init.named_parameters(): 
    param.data = torch.zeros_like(param.data)
    
model_ones_init = NeuralNetwork()
for name, param in model_ones_init.named_parameters(): 
    param.data = torch.ones_like(param.data)

param_hist(model_zero_init, "Zero Init") 
param_hist(model_ones_init, "Ones Init")

# %%
zero_init_acc = run(model_zero_init)
ones_init_acc = run(model_ones_init)
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301034
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301102
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301052
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300923
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301035
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301033
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300976
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301089
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301022
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301150
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.300972
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301028
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301013
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301111
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.301076
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.311939
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.318470
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.318478
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.306714
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 9.8%, Avg loss: 2.320218
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 9.8%, Avg loss: 2.312961
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 9.8%, Avg loss: 2.310658
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.319625
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.309365
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.306576
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.303983
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.310176
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.304938
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.303529
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.304693

# %%
plt.plot(zero_init_acc, label="Zeros") 
plt.plot(ones_init_acc, label="Ones") 
plt.legend() 
plt.ylabel("Accuracy") 
plt.xlabel("Epochs")
plt.ylim(0, 0.15)
plt.show()

# %%
model_bernoulli_1_init = NeuralNetwork() 
for name, param in model_bernoulli_1_init.named_parameters(): 
    param.data = torch.where(param.data < 0.0, 1.0, -1.0)

model_gauss_1_init = NeuralNetwork() 
for name, param in model_gauss_1_init.named_parameters(): 
    param.data = torch.randn_like(param.data) 
    
model_uniform_1_init = NeuralNetwork() 
for name, param in model_uniform_1_init.named_parameters(): 
    param.data = torch.rand_like(param.data) * 2 - 1

# %%
param_hist(model_bernoulli_1_init, "Bernoulli (-1, 1)") 
param_hist(model_gauss_1_init, "Gaussian(0, 1)")
param_hist(model_uniform_1_init, "Uniform(-1, 1)")

# %%
bernoulli_1_init_acc = run(model_bernoulli_1_init) 
gauss_init_acc = run(model_gauss_1_init) 
uniform_init_acc = run(model_uniform_1_init)
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 16.0%, Avg loss: 2.472459
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 17.9%, Avg loss: 2.409574
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 20.5%, Avg loss: 2.274751
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 26.5%, Avg loss: 2.282322
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 28.1%, Avg loss: 2.254701
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 30.5%, Avg loss: 2.207404
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 31.3%, Avg loss: 2.127704
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 2.081472
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 37.3%, Avg loss: 2.058820
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 35.3%, Avg loss: 1.940934
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 37.4%, Avg loss: 1.947893
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.945260
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 41.3%, Avg loss: 1.900858
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 41.3%, Avg loss: 1.816998
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 44.7%, Avg loss: 1.793852
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 45.1%, Avg loss: 1.817454
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 45.7%, Avg loss: 1.783455
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 46.3%, Avg loss: 1.718115
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 49.3%, Avg loss: 1.739430
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 47.5%, Avg loss: 1.723186
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 50.6%, Avg loss: 1.680247
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.777591
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 48.8%, Avg loss: 1.583327
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 51.5%, Avg loss: 1.616608
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 52.5%, Avg loss: 1.623595
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 51.4%, Avg loss: 1.539476
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 52.0%, Avg loss: 1.541476
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 55.1%, Avg loss: 1.561095
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 54.7%, Avg loss: 1.587566
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 54.2%, Avg loss: 1.535209
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 54.8%, Avg loss: 1.518165
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 57.7%, Avg loss: 1.660906
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 55.0%, Avg loss: 1.507976
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 51.0%, Avg loss: 1.686532
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 57.9%, Avg loss: 1.562135
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.568382
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 58.6%, Avg loss: 1.557100
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 58.0%, Avg loss: 1.487649
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 59.2%, Avg loss: 1.501440
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 56.8%, Avg loss: 1.475588
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.453512
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 58.9%, Avg loss: 1.442492
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.521884
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 60.2%, Avg loss: 1.508974
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 63.6%, Avg loss: 1.450948
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 63.7%, Avg loss: 1.395066
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 63.7%, Avg loss: 1.458291
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 1.430008
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 66.4%, Avg loss: 1.379273
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 1.407639
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 23.7%, Avg loss: 2.257393
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 28.7%, Avg loss: 2.053136
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 33.1%, Avg loss: 1.953749
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.892961
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 39.9%, Avg loss: 1.817179
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 41.3%, Avg loss: 1.767769
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 43.7%, Avg loss: 1.693380
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 46.3%, Avg loss: 1.657468
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 47.5%, Avg loss: 1.591334
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 49.5%, Avg loss: 1.590951
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 43.2%, Avg loss: 1.649492
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 50.2%, Avg loss: 1.465416
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 51.4%, Avg loss: 1.425255
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 53.8%, Avg loss: 1.412338
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 53.9%, Avg loss: 1.374614
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 52.0%, Avg loss: 1.454764
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 54.5%, Avg loss: 1.357730
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 54.8%, Avg loss: 1.354912
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 52.8%, Avg loss: 1.411926
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 57.4%, Avg loss: 1.288686
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 58.8%, Avg loss: 1.279802
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 58.4%, Avg loss: 1.219898
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 59.4%, Avg loss: 1.218195
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.232897
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 58.0%, Avg loss: 1.255559
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 59.9%, Avg loss: 1.203712
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 63.6%, Avg loss: 1.191444
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.156354
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 1.118895
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 1.082072
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 66.1%, Avg loss: 1.223230
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 67.5%, Avg loss: 1.039319
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 70.0%, Avg loss: 1.029352
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 71.1%, Avg loss: 1.003254
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 72.9%, Avg loss: 0.900215
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 72.4%, Avg loss: 0.934187
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.924869
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 74.2%, Avg loss: 0.901675
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.928169
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.915795
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.900320
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 73.5%, Avg loss: 0.922374
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 70.2%, Avg loss: 1.015793
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.902582
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 73.9%, Avg loss: 0.888964
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 76.1%, Avg loss: 0.869169
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 75.7%, Avg loss: 0.868542
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.849643
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.852748
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 76.3%, Avg loss: 0.884356
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 66.5%, Avg loss: 1.274967
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 72.8%, Avg loss: 1.029017
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.878149
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.791281
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.716213
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.674768
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.705911
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.619629
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.613185
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.570963
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.550359
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.532471
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.522187
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.521583
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.517241
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.489090
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.484747
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.493800
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.498501
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.466697
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.470723
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.465503
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.440751
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.439468
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.441637
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.423409
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.433229
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.414252
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.426856
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.421374
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.409831
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.408887
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.398056
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.405328
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.389893
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.410512
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.396462
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.414452
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.384184
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.390459
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.389432
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.389425
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.385317
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.374489
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.386330
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.394744
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.399715
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.381699
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.370640
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.382288

# %%
plt.plot(bernoulli_1_init_acc, label="Bernoulli(-1, 1)") 
plt.plot(gauss_init_acc, label="Gaussian(0, 1)") 
plt.plot(uniform_init_acc, label="Uniform(-1, 1)") 
plt.legend() 
plt.ylabel("Accuracy") 
plt.xlabel("Epochs")
plt.ylim(0, 1, 0.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       5 plt.ylabel("Accuracy")
#       6 plt.xlabel("Epochs")
# ----> 7 plt.ylim(0, 1, 0.1)
#       8 plt.show()
#
# File ~/.conda/envs/pytorch-base/lib/python3.10/site-packages/matplotlib/pyplot.py:1983, in ylim(*args, **kwargs)
#    1981 if not args and not kwargs:
#    1982     return ax.get_ylim()
# -> 1983 ret = ax.set_ylim(*args, **kwargs)
#    1984 return ret
#
# TypeError: _AxesBase.set_ylim() takes from 1 to 3 positional arguments but 4 were given

# %%
model_bernoulli_01_init = NeuralNetwork() 
for name, param in model_bernoulli_01_init.named_parameters(): 
    param.data = torch.where(param.data < 0.0, 0.1, -0.1)

model_gauss_01_init = NeuralNetwork() 
for name, param in model_gauss_01_init.named_parameters(): 
    param.data = torch.randn_like(param.data) * 0.1 
    
model_uniform_01_init = NeuralNetwork() 
for name, param in model_uniform_01_init.named_parameters(): 
    param.data = torch.rand_like(param.data) * 0.2 - 0.1
   
param_hist(model_bernoulli_01_init, "Bernoulli (-0.1, 0.1)") 
param_hist(model_gauss_01_init, "Gaussian(0, 0.1)")
param_hist(model_uniform_01_init, "Uniform(-0.1, 0.1)")

# %%
bernoulli_01_init_acc = run(model_bernoulli_01_init) 
gauss_01_init_acc = run(model_gauss_01_init) 
uniform_01_init_acc = run(model_uniform_01_init)
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.278850
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.212754
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.180225
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.161225
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.153426
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.145972
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.128450
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.132895
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.119084
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.112590
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.111307
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.105511
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.106061
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.102829
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.095536
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.096365
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.093633
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.097835
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.091237
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.090496
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.090786
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.093341
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.085741
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.087772
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.085911
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.089693
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.085087
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.085080
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.083724
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.085074
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.084570
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.084134
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.086429
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.085983
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.083980
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.082666
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.081713
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.083013
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.082585
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.084649
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.082686
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.082656
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.084033
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.084648
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.086317
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.082317
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.083657
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.082675
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.083658
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.083170
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.274344
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.226994
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.187553
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.166572
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.152763
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.146897
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.135537
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.135330
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.120498
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.118352
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.114167
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.111472
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.113245
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.108718
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.104517
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.104503
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.100280
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.100882
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.098777
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.099421
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.096743
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.094803
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.096426
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093538
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092834
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092843
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.094127
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.094885
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.093954
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.090025
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.090451
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.090380
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092992
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.091383
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.092436
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.091482
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.091411
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.090410
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.093090
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.091432
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.091442
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.090499
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.090498
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093089
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.091367
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.093064
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.091437
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.096548
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.090894
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.091377
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.306672
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.258318
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.224856
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.189682
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.175872
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.159517
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.152600
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.138781
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131569
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.124631
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.116221
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.114735
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.107891
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.108264
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.100834
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.095763
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.096359
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.093599
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.089777
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.090310
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.086919
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.091772
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.086971
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.084934
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.085830
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.082314
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.083128
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.083374
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.081737
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.076453
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.075539
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.078874
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.078929
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.074593
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.073598
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.076296
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.074028
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.077416
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.072537
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.075000
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.076892
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.076112
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.075049
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.071687
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.074557
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.074750
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.073042
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.073063
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.071520
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.072315

# %%
plt.plot(bernoulli_01_init_acc, label="Bernoulli(-1, 1)") 
plt.plot(gauss_01_init_acc, label="Gaussian(0, 1)") 
plt.plot(uniform_01_init_acc, label="Uniform(-1, 1)") 
plt.legend() 
plt.ylabel("Accuracy") 
plt.xlabel("Epochs")
plt.ylim(0, 1.0)
plt.show()
